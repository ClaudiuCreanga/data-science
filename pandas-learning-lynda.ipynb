# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
series_obj = pd.Series(np.arange(8), index=["row " + str(i) for i in range(1,9)])
series_obj
# Out:
# row 1    0
# row 2    1
# row 3    2
# row 4    3
# row 5    4
# row 6    5
# row 7    6
# row 8    7
# dtype: int64

# %%
series_obj["row 7"]
# Out:
# 6

# %%
series_obj[[0,7]]
# Out:
# row 1    0
# row 8    7
# dtype: int64

# %%
np.random.seed(25)
DF_obj = pd.DataFrame(
    np.random.rand(36).reshape((6,6)), 
    index=["row "+ str(i) for i in range(1,7)], 
    columns=["column "+ str(i) for i in range(1,7)]
)
DF_obj
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column 1</th>
#       <th>column 2</th>
#       <th>column 3</th>
#       <th>column 4</th>
#       <th>column 5</th>
#       <th>column 6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>row 1</th>
#       <td>0.870124</td>
#       <td>0.582277</td>
#       <td>0.278839</td>
#       <td>0.185911</td>
#       <td>0.411100</td>
#       <td>0.117376</td>
#     </tr>
#     <tr>
#       <th>row 2</th>
#       <td>0.684969</td>
#       <td>0.437611</td>
#       <td>0.556229</td>
#       <td>0.367080</td>
#       <td>0.402366</td>
#       <td>0.113041</td>
#     </tr>
#     <tr>
#       <th>row 3</th>
# ...

# %%
DF_obj.loc[["row 2", "row 5"],["column 1"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>row 2</th>
#       <td>0.684969</td>
#     </tr>
#     <tr>
#       <th>row 5</th>
#       <td>0.514244</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
series_obj["row 3":"row 7"]
# Out:
# row 3    2
# row 4    3
# row 5    4
# row 6    5
# row 7    6
# dtype: int64

# %%
DF_obj < .2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column 1</th>
#       <th>column 2</th>
#       <th>column 3</th>
#       <th>column 4</th>
#       <th>column 5</th>
#       <th>column 6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>row 1</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>row 2</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>row 3</th>
#       <td>False</td>
#       <td>False</td>
# ...

# %%
series_obj[series_obj > 6]
# Out:
# row 8    7
# dtype: int64

# %%
DF_obj[DF_obj > 0.2]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column 1</th>
#       <th>column 2</th>
#       <th>column 3</th>
#       <th>column 4</th>
#       <th>column 5</th>
#       <th>column 6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>row 1</th>
#       <td>0.870124</td>
#       <td>0.582277</td>
#       <td>0.278839</td>
#       <td>NaN</td>
#       <td>0.411100</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>row 2</th>
#       <td>0.684969</td>
#       <td>0.437611</td>
#       <td>0.556229</td>
#       <td>0.367080</td>
#       <td>0.402366</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>row 3</th>
#       <td>0.447031</td>
# ...

# %%
series_obj["row 1", "row 5", "row 8"] = 8

# %%
series_obj
# Out:
# row 1    8
# row 2    1
# row 3    2
# row 4    3
# row 5    8
# row 6    5
# row 7    6
# row 8    8
# dtype: int64

# %%
missing = np.nan

# %%
series_obj = pd.Series(["row " + str(i) for i in range(1, 9)])
series_obj[2, 6] = missing
series_obj
# Out:
# 0    row 1
# 1    row 2
# 2      NaN
# 3    row 4
# 4    row 5
# 5    row 6
# 6      NaN
# 7    row 8
# dtype: object

# %%
series_obj.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
DF_obj = pd.DataFrame(np.random.rand(36).reshape((6,6)))
DF_obj
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.559242</td>
#       <td>0.745284</td>
#       <td>0.828346</td>
#       <td>0.823694</td>
#       <td>0.077140</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.309258</td>
#       <td>0.524254</td>
#       <td>0.958092</td>
#       <td>0.883201</td>
#       <td>0.295432</td>
#       <td>0.512376</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.088702</td>
#       <td>0.641717</td>
# ...

# %%
DF_obj.loc[3:5, 0] = missing
DF_obj.loc[1:4, 5] = missing
DF_obj
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.559242</td>
#       <td>0.745284</td>
#       <td>0.828346</td>
#       <td>0.823694</td>
#       <td>0.077140</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.309258</td>
#       <td>0.524254</td>
#       <td>0.958092</td>
#       <td>0.883201</td>
#       <td>0.295432</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.088702</td>
#       <td>0.641717</td>
# ...

# %%
filled_DF = DF_obj.fillna(0)
filled_DF
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.559242</td>
#       <td>0.745284</td>
#       <td>0.828346</td>
#       <td>0.823694</td>
#       <td>0.077140</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.309258</td>
#       <td>0.524254</td>
#       <td>0.958092</td>
#       <td>0.883201</td>
#       <td>0.295432</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.088702</td>
#       <td>0.641717</td>
# ...

# %%
filled_DF = DF_obj.fillna({0: 0.1, 5: 1.25})
filled_DF
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.559242</td>
#       <td>0.745284</td>
#       <td>0.828346</td>
#       <td>0.823694</td>
#       <td>0.077140</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.309258</td>
#       <td>0.524254</td>
#       <td>0.958092</td>
#       <td>0.883201</td>
#       <td>0.295432</td>
#       <td>1.250000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.088702</td>
#       <td>0.641717</td>
# ...

# %%
fill_DF = DF_obj.fillna(method="ffill")
fill_DF
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.559242</td>
#       <td>0.745284</td>
#       <td>0.828346</td>
#       <td>0.823694</td>
#       <td>0.077140</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.309258</td>
#       <td>0.524254</td>
#       <td>0.958092</td>
#       <td>0.883201</td>
#       <td>0.295432</td>
#       <td>0.644862</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.088702</td>
#       <td>0.641717</td>
# ...

# %%
my_df = pd.DataFrame(np.random.rand(36).reshape((6,6))) 
my_df * 10
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.672758</td>
#       <td>0.976990</td>
#       <td>0.440174</td>
#       <td>0.077918</td>
#       <td>0.386085</td>
#       <td>0.325661</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.758764</td>
#       <td>0.283726</td>
#       <td>0.280196</td>
#       <td>0.558928</td>
#       <td>0.131789</td>
#       <td>0.180604</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.437088</td>
#       <td>0.528345</td>
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bokeh.plotting as bk

from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LinearColorMapper,
    BasicTicker,
    PrintfTickFormatter,
    ColorBar,
)

from bokeh.sampledata.unemployment1948 import data
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Jan</th>
#       <th>Feb</th>
#       <th>Mar</th>
#       <th>Apr</th>
#       <th>May</th>
#       <th>Jun</th>
#       <th>Jul</th>
#       <th>Aug</th>
#       <th>Sep</th>
#       <th>Oct</th>
#       <th>Nov</th>
#       <th>Dec</th>
#       <th>Annual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1948</td>
#       <td>4.0</td>
#       <td>4.7</td>
#       <td>4.5</td>
#       <td>4.0</td>
#       <td>3.4</td>
#       <td>3.9</td>
#       <td>3.9</td>
#       <td>3.6</td>
#       <td>3.4</td>
#       <td>2.9</td>
#       <td>3.3</td>
#       <td>3.6</td>
# ...

# %%
data['Year'] = data['Year'].astype(str)
data = data.set_index('Year')
data.drop('Annual', axis=1, inplace=True)
data.columns.name = 'Month'
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Month</th>
#       <th>Jan</th>
#       <th>Feb</th>
#       <th>Mar</th>
#       <th>Apr</th>
#       <th>May</th>
#       <th>Jun</th>
#       <th>Jul</th>
#       <th>Aug</th>
#       <th>Sep</th>
#       <th>Oct</th>
#       <th>Nov</th>
#       <th>Dec</th>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1948</th>
#       <td>4.0</td>
#       <td>4.7</td>
# ...

# %%
years = list(data.index)
months = list(data.columns)
colors = ["#75968f", "#a5bab7", "#c9d9d3", "#e2e2e2", "#dfccce", "#ddb7b1", "#cc7878", "#933b41", "#550b1d"]
TOOLS = "hover,save,pan,box_zoom,reset,wheel_zoom"

# %%
df = pd.DataFrame(data.stack(), columns=['rate']).reset_index()
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Month</th>
#       <th>rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1948</td>
#       <td>Jan</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1948</td>
#       <td>Feb</td>
#       <td>4.7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1948</td>
#       <td>Mar</td>
#       <td>4.5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1948</td>
#       <td>Apr</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1948</td>
#       <td>May</td>
#       <td>3.4</td>
#     </tr>
#     <tr>
# ...

# %%
mapper = LinearColorMapper(palette=colors, low=df.rate.min(), high=df.rate.max())
source = ColumnDataSource(df)
