# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %matplotlib inline

# %%
def dateparse(timestamp: int) -> str:
    date = datetime.datetime.fromtimestamp(float(timestamp))
    return "%d-%d" % (date.year, date.month)

# %%
# load the data

magento2_data = pd.read_csv(
    'data/magento-github/m2-data-dates.csv',
    sep=',',
    header=None,
    names = ["Repo", "Start Date", "Last Commit"],
    dtype = {
        "Repo": "str"
    },
    parse_dates=["Start Date","Last Commit"],
    date_parser=dateparse
)

magento1_data = pd.read_csv(
    'data/magento-github/m1-data-dates.csv',
    sep=',',
    header=None,
    names = ["Repo", "Start Date", "Last Commit"],
    dtype = {
        "Repo": "str"
    },
    parse_dates=["Start Date","Last Commit"],
    date_parser=dateparse
)

# %%
magento2_data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Repo</th>
#       <th>Start Date</th>
#       <th>Last Commit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Genmato/DemoProduct</td>
#       <td>2015-02-01</td>
#       <td>2015-02-01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>GordonLesti/ContentVersion</td>
#       <td>2016-05-01</td>
#       <td>2016-05-01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>PayboxByVerifone/Magento2</td>
#       <td>2016-09-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>letunhatkong/wrm2</td>
#       <td>2016-07-01</td>
#       <td>2016-08-01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>mageup/module-internalpayment</td>
#       <td>2016-12-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>mage2pro/core</td>
#       <td>2016-04-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Smith-and-Associates/amazon-payments-magento-2...</td>
#       <td>2016-11-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>pmclain/module-twilio</td>
#       <td>2017-02-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>compropago/plugin-magento-2</td>
#       <td>2016-01-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>praxigento/mobi_mod_mage2_pv</td>
#       <td>2015-10-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>baldwin-agency/magento2-module-less-js-compiler</td>
#       <td>2016-06-01</td>
#       <td>2016-06-01</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>springbot/magento2-queue</td>
#       <td>2016-03-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Monetra/monetra_magento2</td>
#       <td>2016-06-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Zilus/mage2-blog</td>
#       <td>2016-04-01</td>
#       <td>2016-04-01</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>aohorodnyk/module-debug-comment</td>
#       <td>2015-04-01</td>
#       <td>2015-04-01</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>fontera/m2-bash-completion</td>
#       <td>2016-04-01</td>
#       <td>2016-04-01</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>dealer4dealer/magento2-restapi</td>
#       <td>2016-08-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>the-cocktail-america/magento2_blog</td>
#       <td>2016-05-01</td>
#       <td>2016-05-01</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Instamojo/instamojo-magento-2</td>
#       <td>2016-09-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>dotmailer/dotmailer-magento2-extension</td>
#       <td>2015-11-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>tzyganu/m2-breadcrumbs</td>
#       <td>2014-09-01</td>
#       <td>2015-01-01</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>craigchristenson/magento2-2checkout</td>
#       <td>2016-02-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>ctidigital/magento2-configurator</td>
#       <td>2016-06-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>eltrino/PrintOrder</td>
#       <td>2015-03-01</td>
#       <td>2015-03-01</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>ClaudiuCreanga/magento2-store-locator-stockist...</td>
#       <td>2016-07-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Cotya/ComposerNotifyEndpointModule</td>
#       <td>2015-03-01</td>
#       <td>2015-03-01</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Bogardo/Mailgun-Magento2</td>
#       <td>2016-06-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>cangzhu/lvepay-php</td>
#       <td>2016-10-01</td>
#       <td>2016-10-01</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>pagseguro/magento2</td>
#       <td>2016-02-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Colognetworx/magento2-s3media</td>
#       <td>2017-02-01</td>
#       <td>2017-02-01</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>154</th>
#       <td>inviqa/MX_HelperBar</td>
#       <td>2016-05-01</td>
#       <td>2016-09-01</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>outeredge/magento-additionalproduct-module</td>
#       <td>2016-11-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>156</th>
#       <td>magecodenet/m2-admin-order-fix</td>
#       <td>2016-11-01</td>
#       <td>2016-11-01</td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>fredrikblanco/magemoddemo</td>
#       <td>2015-11-01</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>158</th>
#       <td>Voicyou/ProductViews</td>
#       <td>2017-01-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>159</th>
#       <td>henkelund/magento2-henhed-piwik</td>
#       <td>2015-12-01</td>
#       <td>2017-03-01</td>
#     </tr>
#     <tr>
#       <th>160</th>
#       <td>eboekhouden/magento2-export</td>
#       <td>2016-04-01</td>
#       <td>2016-04-01</td>
#     </tr>
#     <tr>
#       <th>161</th>
#       <td>anupdugar/SampleM2Api</td>
#       <td>2015-02-01</td>
#       <td>2015-02-01</td>
#     </tr>
#     <tr>
#       <th>162</th>
#       <td>magento-hackathon/m2-pretty-url</td>
#       <td>2016-01-01</td>
#       <td>2016-01-01</td>
#     </tr>
#     <tr>
#       <th>163</th>
#       <td>kaviarasankk/Magekmf</td>
#       <td>2017-01-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>164</th>
#       <td>ClaudiuCreanga/magento2-product-stock-import-e...</td>
#       <td>2017-01-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>165</th>
#       <td>Codaone/magento2_logitrail_module</td>
#       <td>2016-12-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>166</th>
#       <td>PartBerlin/Decimal</td>
#       <td>2016-05-01</td>
#       <td>2017-02-01</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>Nabooru/module-address-validation-core</td>
#       <td>2016-01-01</td>
#       <td>2016-01-01</td>
#     </tr>
#     <tr>
#       <th>168</th>
#       <td>Iazel/magento2-regenurl</td>
#       <td>2016-10-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>169</th>
#       <td>jnodwell/TwitterFeed</td>
#       <td>2016-12-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>ritgrad10/dual-category-navigation</td>
#       <td>2016-02-01</td>
#       <td>2016-02-01</td>
#     </tr>
#     <tr>
#       <th>171</th>
#       <td>bashconsole/magento2-recaptcha</td>
#       <td>2017-01-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>172</th>
#       <td>praxigento/mobi_mod_mage2_core</td>
#       <td>2015-10-01</td>
#       <td>2017-04-01</td>
#     </tr>
#     <tr>
#       <th>173</th>
#       <td>shockwavemk/magento2-module-mail</td>
#       <td>2016-01-01</td>
#       <td>2016-10-01</td>
#     </tr>
#     <tr>
#       <th>174</th>
#       <td>lenlorijn/theme-generator</td>
#       <td>2016-09-01</td>
#       <td>2016-09-01</td>
#     </tr>
#     <tr>
#       <th>175</th>
#       <td>cedcommerce/magneto-2-sample-shipping-module</td>
#       <td>2015-09-01</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>176</th>
#       <td>windigo00/module_blog</td>
#       <td>2016-04-01</td>
#       <td>2016-04-01</td>
#     </tr>
#     <tr>
#       <th>177</th>
#       <td>ericthehacker/magento2-configscopehints</td>
#       <td>2015-04-01</td>
#       <td>2017-01-01</td>
#     </tr>
#     <tr>
#       <th>178</th>
#       <td>yireo/Yireo_NewRelic2</td>
#       <td>2015-07-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>179</th>
#       <td>josephmcdermott/Article-Magento2-Payment</td>
#       <td>2015-07-01</td>
#       <td>2015-07-01</td>
#     </tr>
#     <tr>
#       <th>180</th>
#       <td>magento-hackathon/Hackathon_Blog</td>
#       <td>2015-05-01</td>
#       <td>2015-06-01</td>
#     </tr>
#     <tr>
#       <th>181</th>
#       <td>jzahedieh/Magento2-FileConfigurator</td>
#       <td>2015-08-01</td>
#       <td>2015-10-01</td>
#     </tr>
#     <tr>
#       <th>182</th>
#       <td>brunoroeder/magento2-Pagarme</td>
#       <td>2016-12-01</td>
#       <td>2016-12-01</td>
#     </tr>
#     <tr>
#       <th>183</th>
#       <td>mjankiewicz/MagentoConfigurableProduct</td>
#       <td>2016-08-01</td>
#       <td>2016-08-01</td>
#     </tr>
#   </tbody>
# </table>
# <p>184 rows × 3 columns</p>
# </div>

# %%
magento2_data_start_dates = magento2_data.copy()
magento2_data_start_dates.drop(["Last Commit", "Repo"], axis = 1, inplace = True)
magento2_data_start_dates = magento2_data_start_dates.groupby("Start Date").size().to_frame('Total')

# %%
# We can see that the number of repos created was the highest in the middle of 2016

f, ax = plt.subplots(figsize=(12, 8))
ax.plot(magento2_data_start_dates)
ax.set(title='Number of magento2 repos created per month', ylabel='Number of repos')
# Out:
# [<matplotlib.text.Text at 0x11d059320>, <matplotlib.text.Text at 0x11d3cdbe0>]

# %%
# let's see for magento1
# although decreasing hard since begining of 2016, there are still magento1 repos being created

magento1_data_start_dates = magento1_data.copy()
magento1_data_start_dates.drop(["Last Commit", "Repo"], axis = 1, inplace = True)
magento1_data_start_dates = magento1_data_start_dates.groupby("Start Date").size().to_frame('Total')
f, ax = plt.subplots(figsize=(12, 8))
ax.plot(magento1_data_start_dates)
ax.set(title='Number of magento1 repos created per month', ylabel='Number of repos')
# Out:
# [<matplotlib.text.Text at 0x11d3f26d8>, <matplotlib.text.Text at 0x11d5fd780>]

# %%
# plotting the 2 of them together we see that magento2 is struggling to catch up with magento1
# and has a long way until it reaches magento1 highest period when there were up to 60 repos created per month

magento_start_date = pd.merge(magento1_data_start_dates, magento2_data_start_dates, how='outer', left_index=True, right_index=True)

f, ax = plt.subplots(figsize=(12, 8))
ax.plot(magento_start_date)
ax.set(title='Number of magento1 and magento2 repos created', ylabel='Number of repos')
# Out:
# [<matplotlib.text.Text at 0x11d5aa630>, <matplotlib.text.Text at 0x11dab1c18>]

# %%
# but let's see how active are the magento1 repos vs magento2 repos

magento1_data_last_commit = magento1_data.copy()
magento1_data_last_commit.drop(["Start Date", "Repo"], axis = 1, inplace = True)
magento1_data_last_commit = magento1_data_last_commit.groupby("Last Commit").size().to_frame('Total1')

magento2_data_last_commit = magento2_data.copy()
magento2_data_last_commit.drop(["Start Date", "Repo"], axis = 1, inplace = True)
magento2_data_last_commit = magento2_data_last_commit.groupby("Last Commit").size().to_frame('Total2')

magento_last_commit = pd.merge(magento1_data_last_commit, magento2_data_last_commit, how='outer', left_index=True, right_index=True)

f, ax = plt.subplots(figsize=(12, 8))
ax.plot(magento_last_commit)
ax.set(title='Number of magento1 repos with last activity this month', ylabel='Number of repos')
# Out:
# [<matplotlib.text.Text at 0x11d443b70>, <matplotlib.text.Text at 0x11da40c88>]

# %%
from github import Github
import csv
import time

with open('data/magento-github/magento2-modules.csv', 'r') as f:
    reader = csv.reader(f)
    module_list = list(reader)

g = Github("ClaudiuCreanga", "code")

phpspec_tested_modules = []

for index,module in enumerate(module_list):
    if index % 20 == 0:
        time.sleep(5)
    repo = g.get_repo(module[0])
    if repo.get_contents("/"):
        phpspec = g.search_code("PHPUnit in:file repo:%s" % module[0])
        try:
            list(phpspec)
            if len(list(phpspec)):
                phpspec_tested_modules.append(module[0])
        except:
            pass

with open('data/magento-github/unit.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(phpspec_tested_modules)

# %%
obj_manager_modules = []

for index,module in enumerate(module_list):
    if index % 20 == 0:
        time.sleep(5)
    repo = g.get_repo(module[0])
    if repo.get_contents("/"):
        obj = g.search_code("\Magento\Framework\App\ObjectManager in:file language:php repo:%s" % module[0])
        try:
            list(obj)
            if len(list(obj)):
                obj_manager_modules.append(module[0])
        except:
            pass

with open('data/magento-github/object_manager.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(obj_manager_modules)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-197-1ac27f018731> in <module>()
#       3 for index,module in enumerate(module_list):
#       4     if index % 20 == 0:
# ----> 5         time.sleep(5)
#       6     repo = g.get_repo(module[0])
#       7     if repo.get_contents("/"):
#
# KeyboardInterrupt:

# %%
# code quality
# how many use the object manager directly or do unit tests

def percentage(part, whole):
  return int(100 * float(part)/float(whole))

quality = pd.DataFrame.from_records([{"All":184 , "PhpSpec": 5, "PhpUnit": 44, "ObjectManager":52}])
ax = quality.plot(kind="bar", title="Quality of magento2 repos", figsize=(15,10), legend=True)
for p in ax.patches:
    ax.annotate(str(int(p.get_height())) +" ("+ str(percentage(p.get_height(), 184)) + "% )", ((p.get_x()), int(p.get_height() + 1)))
# Out:
# 184.0
# 52.0
# 5.0
# 44.0

# %%
all_modules = pd.DataFrame([{"magento1": 1168, "magento2": 184}])
ax = all_modules.plot(kind="bar", title="Total number of magento1 and magento2 modules", figsize=(15,10), legend=True)
for p in ax.patches:
    ax.annotate(str(int(p.get_height())) +" ("+ str(percentage(p.get_height(), 1168)) + "% )", ((p.get_x()), int(p.get_height() + 1)))
