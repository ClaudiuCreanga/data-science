# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data/gender-pay-gap/UK Gender Pay Gap Data - 2017 to 2018.csv")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EmployerName</th>
#       <th>Address</th>
#       <th>CompanyNumber</th>
#       <th>SicCodes</th>
#       <th>DiffMeanHourlyPercent</th>
#       <th>DiffMedianHourlyPercent</th>
#       <th>DiffMeanBonusPercent</th>
#       <th>DiffMedianBonusPercent</th>
#       <th>MaleBonusPercent</th>
#       <th>FemaleBonusPercent</th>
#       <th>...</th>
#       <th>MaleLowerMiddleQuartile</th>
#       <th>FemaleLowerMiddleQuartile</th>
#       <th>MaleUpperMiddleQuartile</th>
#       <th>FemaleUpperMiddleQuartile</th>
#       <th>MaleTopQuartile</th>
#       <th>FemaleTopQuartile</th>
# ...

# %%
df.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName'],
#       dtype='object')

# %%
df = df.drop(["Address", "CompanyNumber", "ResponsiblePerson"], axis=1)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EmployerName</th>
#       <th>SicCodes</th>
#       <th>DiffMeanHourlyPercent</th>
#       <th>DiffMedianHourlyPercent</th>
#       <th>DiffMeanBonusPercent</th>
#       <th>DiffMedianBonusPercent</th>
#       <th>MaleBonusPercent</th>
#       <th>FemaleBonusPercent</th>
#       <th>MaleLowerQuartile</th>
#       <th>FemaleLowerQuartile</th>
#       <th>MaleLowerMiddleQuartile</th>
#       <th>FemaleLowerMiddleQuartile</th>
#       <th>MaleUpperMiddleQuartile</th>
#       <th>FemaleUpperMiddleQuartile</th>
#       <th>MaleTopQuartile</th>
#       <th>FemaleTopQuartile</th>
#       <th>CompanyLinkToGPGInfo</th>
# ...

# %%
df[df["EmployerName"].str.contains("FACEBOOK")]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EmployerName</th>
#       <th>SicCodes</th>
#       <th>DiffMeanHourlyPercent</th>
#       <th>DiffMedianHourlyPercent</th>
#       <th>DiffMeanBonusPercent</th>
#       <th>DiffMedianBonusPercent</th>
#       <th>MaleBonusPercent</th>
#       <th>FemaleBonusPercent</th>
#       <th>MaleLowerQuartile</th>
#       <th>FemaleLowerQuartile</th>
#       <th>MaleLowerMiddleQuartile</th>
#       <th>FemaleLowerMiddleQuartile</th>
#       <th>MaleUpperMiddleQuartile</th>
#       <th>FemaleUpperMiddleQuartile</th>
#       <th>MaleTopQuartile</th>
#       <th>FemaleTopQuartile</th>
#       <th>CompanyLinkToGPGInfo</th>
# ...

# %%
siccodes = pd.read_csv("data/gender-pay-gap/siccode.csv")
siccodes.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>section</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1110</td>
#       <td>A</td>
#       <td>Growing of cereals (except rice), leguminous c...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1120</td>
#       <td>A</td>
#       <td>Growing of rice</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1130</td>
#       <td>A</td>
#       <td>Growing of vegetables and melons, roots and tu...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1140</td>
#       <td>A</td>
# ...

# %%
df["sector"] = df.apply(lambda row: siccodes[siccodes["code"] == row["SicCodes"]]["section"] if siccodes[siccodes["code"] == row["SicCodes"]]["section"].any() else np.nan, axis=1)
df["sector"].head()
# Out:
# /Users/ccreanga/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-fc53136933a0> in <module>()
# ----> 1 df["sector"] = df.apply(lambda row: siccodes[siccodes["code"] == row["SicCodes"]]["section"] if siccodes[siccodes["code"] == row["SicCodes"]]["section"].any() else np.nan, axis=1)
#       2 df["sector"].head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
# ...

# %%
np.random.seed(0)
da = pd.DataFrame(np.random.rand(3,3))
da1 = pd.DataFrame(np.random.rand(3,3))
da
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.548814</td>
#       <td>0.715189</td>
#       <td>0.602763</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.544883</td>
#       <td>0.423655</td>
#       <td>0.645894</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.437587</td>
#       <td>0.891773</td>
#       <td>0.963663</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
da1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.383442</td>
#       <td>0.791725</td>
#       <td>0.528895</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.568045</td>
#       <td>0.925597</td>
#       <td>0.071036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.087129</td>
#       <td>0.020218</td>
#       <td>0.832620</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
da1["nu"] = da1.apply(lambda row: da1[da1[0] == row[0]][2] if da1[da1[0] == row[0]][2].any() else np.nan, axis=1)

# %%
da1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>nu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.383442</td>
#       <td>0.791725</td>
#       <td>0.528895</td>
#       <td>0.528895</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.568045</td>
#       <td>0.925597</td>
#       <td>0.071036</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.087129</td>
#       <td>0.020218</td>
#       <td>0.832620</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>
